# %%
### Text adventure game Felix Boelck

## first creating a Doc String to give the user some genereal information.

"""
Created on Tue Jan 25 13:12:42 2022

@author: Felix.Boelck
"""

"""
    DocString:
    
    A) Introduction:
    Hello and welcome to my text adventure game!
    This game is based on the movie Star Wars - Revenge of the Sith.
    It consists of three stages, and it also has defined functions
    for start, win, and lose. This game requires belief, anger and
    not as much common sense as you would think. Also having a
    little bit of knowledge from the movie will be helpful.
    
    Round 1: Choose to follow the light or dark side.
    Round 2: Get on the side of JEDI's or Sith's.
    Round 3: Become Darth Vader.
    
    B) Known Bugs and/or Errors:
    Doesnt always recognize all Inputs for the questions. 
    
"""

## Printing a short introduction to the game. To get the user hyped up for the game.
print(r"""
.        .          .    .    .            .            .                   .
               .               ..       .       .   .             .
 .      .     T h i s   i s   t h e   g a l a x y   o f   . . .             .
                     .              .       .                    .      .
.        .               .       .     .            .
   .           .        .                     .        .            .
             .               .    .          .              .   .         .
               _________________      ____         __________
 .       .    /                 |    /    \    .  |          \
     .       /    ______   _____| . /      \      |    ___    |     .     .
             \    \    |   |       /   /\   \     |   |___>   |
           .  \    \   |   |      /   /__\   \  . |         _/               .
 .     ________>    |  |   | .   /            \   |   |\    \_______    .
      |            /   |   |    /    ______    \  |   | \           |
      |___________/    |___|   /____/      \____\ |___|  \__________|    .
  .     ____    __  . _____   ____      .  __________   .  _________
       \    \  /  \  /    /  /    \       |          \    /         |      .
        \    \/    \/    /  /      \      |    ___    |  /    ______|  .
         \              /  /   /\   \ .   |   |___>   |  \    \
   .      \            /  /   /__\   \    |         _/.   \    \            +
           \    /\    /  /            \   |   |\    \______>    |   .
            \  /  \  /  /    ______    \  |   | \              /          .
 .       .   \/    \/  /____/      \____\ |___|  \____________/  FB
                               .                                        .
    
    "War! The Republic is crumbling
     under attacks by the ruthless
     Sith Lord, Count Dooku.
     There are heroes on both sides.
     Evil is everywhere.

     In a stunning move, the
     fiendish droid leader, General
     Grievous, has swept into the
     Republic capital and kidnapped
     Chancellor Palpatine, leader of
     the Galactic Senate.

     As the Separatist Droid Army
     attempts to flee the besieged
     capital with their valuable
     hostage, two Jedi Knights lead a
     desperate mission to rescue the
     captive Chancellor...."

""")

## Importing time package 
import time

##installing emoji package
# !pip install emoji

## Importing emoji package 
import emoji

## import random package
import random

## Name input

name = str(input(prompt = """
        - Enter your first name: """))

name = name.title()

ls_duell = 10

## printing the introduction into the game
print(f"""
 {"*" * 110}

 Hello JEDI {name}! It is a pleasure having you here today! I hope you are having fun while playing.
 In this game you will dive into the mysterious world of the JEDI's and hopefully help them to succeed 
 in one of their toughest and most important missions.
                  ___       ___     ___  __   __   __   ___     __   ___           ___              __        
 |\/|  /\  \ /     |  |__| |__     |__  /  \ |__) /  ` |__     |__) |__     |  | |  |  |__|    \ / /  \ |  |  
 |  | /~~\  |      |  |  | |___    |    \__/ |  \ \__, |___    |__) |___    |/\| |  |  |  |     |  \__/ \__/ .

 {"*" * 110}\n
      
      """)
# starting off the game
input(prompt = """
        Start the game by pressing Enter""")


## defining the first room as Coruscant
def Coruscant():
    print("""
    
 While the Galactic Republic is in the midst of the epic war with the 
 Confederacy of Independent Systems under the leadership of Count Dooku,
 who is also the Sith Lord, Darth Tyranus. You're on a mission to rescue 
 the kidnapped Supreme Chancellor Palpatine from Dooku's ship!
 Options:
    \n""")
    
    #input(prompt = """<Trust in the FORCE to find the right key to continue.
                       #Afterwards press ENTER.\n""")
    ## printing the different options for the player to choose
    print("""
        (1) Try and fight your way through the Separatist armada.""")
    
    print("""
        (2) You are too scared and want to quit.""")
    
    print("""
        (3) Want to see something really cool.""")
    
    ## asking for the players choice
    choice = input(prompt = "> ")
    
    # depending on the user choice either moving on to fight, leave or show him something ascii art
    
    if choice == '1' or 'one' in choice.casefold() or 'try' in choice.casefold() or 'fight' in choice.casefold() or 'separatist' in choice.casefold():
        
        # declaring an object
        droids_fight = 0

        # looping while count is greater than zero
        while droids_fight < 23:
            
            # counting the crashed droids
            droids_fight = droids_fight + 1
            
            ## printing collision emojis
            print(emoji.emojize(':collision:'), droids_fight)
        
            # sleeping the kernel
            time.sleep(0.18)

        # returing the success message that the player crushed 23 droids
        print("""
        
 Great you smashed and crushed 23 droids coming here. Great success!""")
        
        # giving instructions on what comes next 
        print("""
 Wow, that was a tough fight for the start. But hey you made it through the battles and 
 even found a way onto the bridge of the ship. Here Chancellor Palpatine is being held hostage. 
 Before you can rescue him, you have to fight the powerful Sith Lord Count Dooku.\n""")
        
        # giving a message to inform the player about the next fight
        input(prompt = """
        Get ready for the fight with Dooku. Your JEDI master counts on you.
                    
                    
        Press Enter to start the fight.\n""")
        
        # describing the fight and giving the player 2 options to choose from
        print(f"""
 {"*" * 110}
 
 You got into an epic lightsword fight. Your master and friend Obi Wan is laying unconscious on the
 ground. Nevertheless, you managed to beat Dooku! Through a cunning move, where you cut off both of
 his hands. 
    
 Now he kneels in the front of you and you got to decide if you want to let him alive or kill him. 
 The codex of the JEDI tells you not to. Instead you should take him hostage and bring him back 
 to the JEDI temple. But Chancellor Palpatine insists that you kill him. Which side of the FORCE 
 will you choose?
    
        1) Light side (let Dooku live and escort him to the JEDI temple {emoji.emojize(':sparkles:')})
        2) Dark side (use both light sabers to cut off his head {emoji.emojize(':skull:')})
        
 """)
        ## asking for user input
        choice = input(prompt = "> ")
        
        # starting the nested conditional statement 
        # using if condition to define option 1
        if '1' in choice.casefold() or 'one' in choice.casefold() or 'light' in choice.casefold() or 'dooku' in choice.casefold():
            
            print(f"Strong the FORCE is in you. You are on the way to become a powerful and fair JEDI {emoji.emojize(':full_moon:')}")
            ## sending the player back to the stage fail
            fail()
 
           
        # using elif condition to define option 2  
        elif '2' in choice.casefold() or 'two' in choice.casefold() or 'dark' in choice.casefold() or 'cut' in choice.casefold() or 'light sabers' in choice.casefold():
            print(f"""

 You went with your anger and chose to cut of his head.
    
 {emoji.emojize(':skull:') * 45}

 "Be aware of the dark side. Anger, fear, aggression… the dark side of the Force are they, 
 easily they flow.", Yoda says. So watch out and think carefully young Padawan {name}.
    
 {emoji.emojize(':skull:') * 45}

 """)
            # using input statement to structure the text and making it more readable/interactive for the
            # player
                                                          ^^^^ o777777o ^^^
                                                          o77777iiiiii7777o
                                                         7777iiii88888iii777
                                                        ;;;i7778888888877ii;;
                                                       [i77888888^^^^8888877i]
                                                       77888^oooo8888oooo^8887]
                                                      [788888888888888888888888]
                                                      88888888888888888888888888
                                                      ]8888888^iiiiiiiii^888888]
                                                        iiiiiiiiiiiiiiiiiiiiii
                                                            ^^^^^^^^^^^^^
        
        """)
        
        # input statement to give player advice and start again at first stage
        input(prompt = """
        
        OK but now enough of the fun. Try to think like a JEDI this time.
        
        Press Enter to continue.""")
        ## sending the player back to the stage Coruscant
        Coruscant() 
    
    ## using the else condition again to remind the player that just number 1 or 2 or are accepted
    else:
        print("Invalid entry. Try again.\n")
        ## sending the player back to the stage Coruscant
        Coruscant()
    

## defining stage 2
def Sidious_revealed():
    print(f""" 
 {"*" * 110}   
 
 After returning to Coruscant with the Chancellor, you are being praised and celebrated as a hero.
 But what makes you even happier are the news from your love Padme. She is pregnant!  
    
    """)
    # input again to strucutre. user can press any number and enter
    while True:
        print("""
 Guess how many children you will get?
        """)
        choice = input(prompt = "> ")

    # try and except function to guess the number of children
        try:
            choice = int(choice)
            if choice == 2:
                print("""
    Congratulations. That was right. You are becoming father of 2 beautiful children.""")
                ## breaking the while loop
                break
            
            # little easter egg hihi
            elif choice == 69:
                print("""
    You are really dirty minded. Be honest that wasn't aboout the children.
    """)
            # choice too high, giving hint
            elif choice > 2:
                print("""
    This was too high. Try again.""")
            
            # choice too lwo, giving hint
            elif choice < 2:
                print("""
    That was too low. Try again.""")
            
            ## else statement because you need one, even though it will never fire :D
            else:
                print("\n    That wasn't a proper input.\n")
                continue
        
        ### except function giving the user hints that only numbers are accepted
        except:
            print("\nThat wasn't a proper input. Hint: Use numbers.\n")
            continue

    ### print the next story part
    print(f"""
 {"*" * 110} 
 
 A few days pass. Thanks to the Chancellor you are promoted in the rank of a JEDI knight and 
 become the youngest member of the JEDI council. 

 Still, you are feeling betrayed. You think you earned the rank of a JEDI master. Moreover, you are 
 having dream predictions of Padme dying while giving birth to your children. This feeds your anger even more.
 You don't want this prophecy to become true. But it seems like the Chancellor knows a way to help you.

    """)
    
    # input for structuring with a phrase this time, enter to continue
    input(prompt = """
 The dark side of the force is a pathway to many abilities some consider to be unnatural. 
 Press Enter to continue.\n""")
    
    # print part of story line
    print(f"""

 {"*" * 110}
 
 Which rings alarm bells. Only Sith lords know the ways of the dark side.

 You decide to reveal your findings to the council. They don't hesitate and try to put the Chancellor
 under arrest. 

 A JEDI troop is sent to arrest him. It turns out that he is the looked for Sith. But he is stronger than
 expected and kills three of the four JEDI's in the battle. Just you and Master Windoo are left. Windoo and 
 Palpatine are in an intense fight. So you have to decide:

    """)
    
    ## printing the different options 
    print("1) Support Palpatine, but let down Master Windoo.")
    print("2) Support Master Windoo, and lose the chance to learn the needed skill to safe Padme.")
    print("3) Let the two squabblers work it out between themselves and ask Yoda for help instead.")

    ## creating choice variable
    choice = input(prompt = "> ")
    
    # if statement moves you to final stage
    if choice == '1' or 'one' in choice.casefold() or 'palpatine' in choice.casefold() or 'let down' in choice.casefold():
        final_fight()
        
    # elif statement makes you fail
    elif choice == '2' or 'two' in choice.casefold() or 'windoo' in choice.casefold() or 'lose' in choice.casefold():
        fail()
    # elif statement to display option 3
    elif choice == '3' or 'three' in choice.casefold() or 'squabblers' in choice.casefold() or 'yoda' in choice.casefold() or 'help' in choice.casefold():
        print(fr""" 

 {"*" * 110}
 
 You chose to let them work that out between themselves and return back to the JEDI temple to ask
 Yoda for help. Once you arrive there he just tells you appalled:
 
                            ____
                         _.' :  `._
                     .-.'`.  ;   .'`.-.
            __      / : ___\ ;  /___ ; \      __
          ,'_ ""--.:__;".-.";: :".-.":__;.--"" _`,
          :' `.t""--.. '<@.`;_  ',@>` ..--""j.' `;
               `:-.._J '-.-'L__ `-- ' L_..-;'
                 "-.__ ;  .-"  "-.  : __.-"
                     L ' /.------.\ ' J
                      "-.   "--"   .-"
                     __.l"-:_JL_;-";.__
                  .-j/'.;  ;''''  / .'\"-.
                .' /:`. "-.:     .-" .';  `.
             .-"  / ;  "-. "-..-" .-"  :    "-.
          .+"-.  : :      "-.__.-"      ;-._   \
          ; \  `.; ;                    : : "+. ;
          :  ;   ; ;                    : ;  : \:
         : `."-; ;  ;                  :  ;   ,/;
          ;    -: ;  :                ;  : .-"'  :
          :\     \  : ;             : \.-"      :
           ;`.    \  ; :            ;.'_..--  / ;
           :  "-.  "-:  ;          :/."      .'  :
             \       .-`.\        /t-""  ":-+.   :
              `.  .-"    `l    __/ /`. :  ; ; \  ;
                \   .-" .-"-.-"  .' .'j \  /   ;/
                 \ / .-"   /.     .'.' ;_:'    ;
                  :-""-.`./-.'     /    `.___.'
                        \ `t  ._  / 
                         "-.t-._:'
    


                                  
 “To be JEDI is to face the truth, and choose. Give off light, or darkness, Padawan. 
                      Be a candle, or the night.”
        
        """)
        
        # using input statement to giving user second chance
        input(prompt = """
        You get a second chance. But this time, go with the force and trust in your own decisions! 
                     Press Enter to start again.""")
        
        ## sending the player back to the stage Coruscant
        Coruscant()
   
    # else statement for invalid entry, brings you back to beginning of stage   
    else:
        print("Invalid entry. Please try again. Hint: Use only the number 1, 2 or 3.\n")
        ## sending the player back to the stage Sidious_revealed
        Sidious_revealed()


#  defining final stage (stage 3)
def final_fight():
    ## printing the intro for the third stage
    print(f"""
 {"*" * 110}
 
 You choose love over friendship, quite romantic. And once more, you come closer to the dark side.
 But the downside is Palpatine tricked you and Master Windoo died in the battle.

 Now Palpatine turns to you and says:

 "The Force is strong with you. A powerful Sith you will become {name}. 
 
         Henceforth, you shall be known as Darth… Vader.
         
  To successfully transform into him, you now have to guess his favorite number."
 \n""")
    
    ## user has to interact via enter to arise as Darth Vader
    ## assigning a random number to the variable number
    number = random.randint(1, 100)
    
    ## creating variable numer of guesses
    number_of_guesses = 0
    print("Okay! Guess Darth Vader's favorite number between 1 to 100:")
    
    ## creating a while loop to let the player guess the random number several times
    while True:
        ## asking player for his guess and save it into variable guess
        guess = input(prompt = ' ')
        ## creating nother variable to count number of guesses of player
        number_of_guesses += 1
        try:
            ## transforming players guess into an integer
            guess = int(guess)
            ## if statement for right answer
            if guess == number:
                print('You guessed the number in ' + str(number_of_guesses) + ' tries!')
                ## break argument to end loop
                break
            ## elif statement to give player hint that guess is too low
            elif guess < number:
                print('Your guess is too low')
            ## else statement togive player hint that guess is too high
            elif guess > number:
                print('Your guess is too high') 
            else:
                ## break argument to end loop
                break
        ## except used for wrong input, give player hint that just numbers are excepted 
        except:
            print('That was a wrong input. Please enter just numbers.')
            ## continue argument to let player keep guessing
            continue

    ## opening win stage    
    win()
  
    
    
        
# defining the win function with winning text      
def win():
    print(f""" 
    
 {"*" * 110}
    
    You SUCCESSFULLY COMPLETED the game. Congratulations. 
    
 You were the CHOSEN ONE! It was said that you would destroy the Sith,
 not join them! Bring balance to the Force, not leave it in darkness!
 
 But hey not every story has a happy ending. 
 
 Now enjoy being one of the most powerful Sith lords of all time. 
 """)
    ## and little ASCII art added to win function
    print(r""" 
 |                       .-.
 |                      |_:_|
 |                     /(_Y_)\
 |.                   ( \/M\/ )
 | '.               _.'-/'-'\-'._
 |   ':           _/.--'[[[[]'--.\_
 |     ':        /_'  : |::"| :  '.\
 |       ':     //   ./ |oUU| \.'  :\
 |         ':  _:'..' \_|___|_/ :   :|
 |           ':.  .'  |_[___]_|  :.':\
 |            [::\ |  :  | |  :   ; : \
 |             '-'   \/'.| |.' \  .;.' |
 |             |\_    \  '-'   :       |
 |             |  \    \ .:    :   |   |
 |             |   \    | '.   :    \  |
 |             /       \   :. .;       |
 |            /     |   |  :__/     :  \\
 |           |  |   |    \:   | \   |   ||
 |          /    \  : :  |:   /  |__|   /|
 |         |     : : :_/_|  /'._\  '--|_\
 |          /___.-/_|-'   \  \
 |                         '-'
 |
 “Don’t be too proud of this technological terror you’ve constructed. 
  The ability to destroy a planet is insignificant next to the power of the Force.”
                         """)




# defining the fail function with text 
def fail():
    print(f"""
 "The greatest teacher, failure is.", YODA
 
 A good JEDI you are becoming. You are using your Midi-chlorians (Cells of the force) 
 in the right way. The Jedi council is proud of you. 

 P.S.: According to the movie, you are not supposed to fulfill the proficiency.
 That's why you "FAILED" in this game. But we are looking forward to hear about your story in the future.
 """)
    ## open input field to exit
    input(prompt = '<Press any key to exit>\n')

# defining the fail_1 function with thext
def fail_1():
    print("""
 "The greatest teacher, failure is.", YODA
 
 What a pitty. A high concentration of Midi-chlorians (Cells of the force) I sensed in you.

 Come back when you are keen to try it.
 """)
    ## open input field to exit
    input(prompt = '<Press any key to exit>\n')

## opening the stage coruscant
Coruscant()
# Out:
# .        .          .    .    .            .            .                   .
#                .               ..       .       .   .             .
#  .      .     T h i s   i s   t h e   g a l a x y   o f   . . .             .
#                      .              .       .                    .      .
# .        .               .       .     .            .
#    .           .        .                     .        .            .
#              .               .    .          .              .   .         .
#                _________________      ____         __________
#  .       .    /                 |    /    \    .  |          \
#      .       /    ______   _____| . /      \      |    ___    |     .     .
#              \    \    |   |       /   /\   \     |   |___>   |
#            .  \    \   |   |      /   /__\   \  . |         _/               .
#  .     ________>    |  |   | .   /            \   |   |\    \_______    .
# ...
